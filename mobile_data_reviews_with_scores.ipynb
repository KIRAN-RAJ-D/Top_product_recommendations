# %%
import pandas as pd
from textblob import TextBlob

# Load the data
df = pd.read_csv('mobile_data_reviews_cleaned.csv')

# Function to get sentiment
def get_sentiment(review):
    analysis = TextBlob(review)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Apply the function to the review column
df['Sentiment'] = df['Review'].apply(get_sentiment)

# Save the updated DataFrame to a new CSV file
df.to_csv('mobile_data_reviews_with_sentiment.csv', index=False)

# Display the first few rows to verify
print(df[['Review', 'Sentiment']].head())
# Out:
#                                               Review Sentiment
# 0              Awesome very happy with this products  Positive
# 1  The phone is perfect at this price range excep...  Positive
# 2  Here are a few observations in a few daysPros ...  Positive
# 3  Camera is very very Good I'm giving 5 star in ...  Positive
# 4            Very well smartphone for great features  Positive

# %%
df
# Out:
#                                                 Review  Rating  \
# 0                Awesome very happy with this products       4
# 1    The phone is perfect at this price range excep...       4
# 2    Here are a few observations in a few daysPros ...       4
# 3    Camera is very very Good I'm giving 5 star in ...       4
# 4              Very well smartphone for great features       5
# ..                                                 ...     ...
# 586  Worth it (Post discounted price)Camera and use...       5
# 587              Very worst performance Weste of money       1
# 588  After using 1 week there is problem in mobile ...       2
# 589                        Camera and Pixel Experience       5
# 590  Good ProductWorst Flipkart PackageBattery rech...       4
#
#            One-word Review        Product ID Sentiment
# 0              Pretty good  MOBGKQZFJ5PXSFBX  Positive
# 1              Pretty good  MOBGKQZFJ5PXSFBX  Positive
# 2          Value-for-money  MOBGKQZFJ5PXSFBX  Positive
# 3              Pretty good  MOBGKQZFJ5PXSFBX  Positive
# 4    Mind-blowing purchase  MOBGKQZFJ5PXSFBX  Positive
# ..                     ...               ...       ...
# 586                Awesome  MOBGZCQMZXYXCZCH  Positive
# 587       Terrible product  MOBGZCQMZXYXCZCH  Negative
# 588               Not good  MOBGZCQMZXYXCZCH  Positive
# 589              Just wow!  MOBGZCQMZXYXCZCH   Neutral
# 590              Wonderful  MOBGZCQMZXYXCZCH  Positive
#
# [591 rows x 5 columns]

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('mobile_data_reviews_with_sentiment.csv')

# Define the sentiment score mapping
sentiment_scores = {
    'Positive': 1,
    'Neutral': 0,
    'Negative': -1
}

# Map the Sentiment column to sentiment scores
df['Sentiment_Score'] = df['Sentiment'].map(sentiment_scores)

# Display the first few rows to verify
print(df.head())

# Optionally, save the updated DataFrame to a new CSV
df.to_csv('mobile_data_reviews_with_scores.csv', index=False)
# Out:
#                                               Review  Rating  \
# 0              Awesome very happy with this products       4
# 1  The phone is perfect at this price range excep...       4
# 2  Here are a few observations in a few daysPros ...       4
# 3  Camera is very very Good I'm giving 5 star in ...       4
# 4            Very well smartphone for great features       5
#
#          One-word Review        Product ID Sentiment  Sentiment_Score
# 0            Pretty good  MOBGKQZFJ5PXSFBX  Positive                1
# 1            Pretty good  MOBGKQZFJ5PXSFBX  Positive                1
# 2        Value-for-money  MOBGKQZFJ5PXSFBX  Positive                1
# 3            Pretty good  MOBGKQZFJ5PXSFBX  Positive                1
# 4  Mind-blowing purchase  MOBGKQZFJ5PXSFBX  Positive                1

# %%
df=pd.read_csv("mobile_data_reviews_with_scores.csv")
df
# Out:
#                                                 Review  Rating  \
# 0                Awesome very happy with this products       4
# 1    The phone is perfect at this price range excep...       4
# 2    Here are a few observations in a few daysPros ...       4
# 3    Camera is very very Good I'm giving 5 star in ...       4
# 4              Very well smartphone for great features       5
# ..                                                 ...     ...
# 586  Worth it (Post discounted price)Camera and use...       5
# 587              Very worst performance Weste of money       1
# 588  After using 1 week there is problem in mobile ...       2
# 589                        Camera and Pixel Experience       5
# 590  Good ProductWorst Flipkart PackageBattery rech...       4
#
#            One-word Review        Product ID Sentiment  Sentiment_Score
# 0              Pretty good  MOBGKQZFJ5PXSFBX  Positive                1
# 1              Pretty good  MOBGKQZFJ5PXSFBX  Positive                1
# 2          Value-for-money  MOBGKQZFJ5PXSFBX  Positive                1
# 3              Pretty good  MOBGKQZFJ5PXSFBX  Positive                1
# 4    Mind-blowing purchase  MOBGKQZFJ5PXSFBX  Positive                1
# ..                     ...               ...       ...              ...
# 586                Awesome  MOBGZCQMZXYXCZCH  Positive                1
# 587       Terrible product  MOBGZCQMZXYXCZCH  Negative               -1
# 588               Not good  MOBGZCQMZXYXCZCH  Positive                1
# 589              Just wow!  MOBGZCQMZXYXCZCH   Neutral                0
# 590              Wonderful  MOBGZCQMZXYXCZCH  Positive                1
#
# [591 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'Rating' is a column in the DataFrame
plt.figure(figsize=(8, 6))
sns.countplot(x='Rating', data=df, palette='viridis')
plt.title('Distribution of Product Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\kiran\AppData\Local\Temp\ipykernel_14372\1022603274.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating', data=df, palette='viridis')

# %%
# Assuming 'Sentiment_Score' is the column with mapped scores
plt.figure(figsize=(8, 6))
sns.countplot(x='Sentiment_Score', data=df, palette='coolwarm')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Sentiment Score')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\kiran\AppData\Local\Temp\ipykernel_14372\2159743428.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment_Score', data=df, palette='coolwarm')

# %%
# Calculate the average rating for each sentiment category
avg_rating_by_sentiment = df.groupby('Sentiment')['Rating'].mean()

# Plot the average ratings by sentiment
plt.figure(figsize=(8, 6))
avg_rating_by_sentiment.plot(kind='bar', color=['red', 'orange', 'green'])
plt.title('Average Rating by Sentiment Category')
plt.xlabel('Sentiment')
plt.ylabel('Average Rating')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'], bins=5, kde=True, color='blue')
plt.title('Rating Distribution of Products')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()
